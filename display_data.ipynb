# %%
import matplotlib.pyplot as plt

loss = []
validation_loss = []

plt.plot(loss, label='Loss')
plt.plot(validation_loss, color='orange', label='Validation Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.xticks(range(len(loss)), range(1, len(loss)+1))
middle_epoch = 9
plt.axvline(x=middle_epoch, color='red', linestyle='--')

plt.text(middle_epoch, max(max(loss), max(validation_loss)), 'Tune model on larger images', horizontalalignment='right', color='red')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 18
#      15 plt.axvline(x=middle_epoch, color='red', linestyle='--')
#      17 # Add text label for the vertical line
# ---> 18 plt.text(middle_epoch, max(max(loss), max(validation_loss)), 'Tune model on larger images', horizontalalignment='right', color='red')
#      20 plt.show()
#
# ValueError: max() arg is an empty sequence

# %%
import numpy as np

y_pred = np.linspace(-2, 2, 400)
y_true = 0  

L1_loss = np.abs(y_true - y_pred)

plt.plot(y_pred, L1_loss, label='L1 Loss')

plt.legend()

plt.xticks([])
plt.yticks([])

plt.show()
